# %%
import torch # PyTorch Implemented using pyTorch
from IPython.display import  Image

# %%
# !git clone https://github.com/ultralytics/yolov5  
# %cd yolov5
# %pip install -r requirements.txt  # install requirement
# Out:
# /Users/akhilsharma/Projects/Mask-NoMask-YOLO/yolov5

# %%
# !python train.py --img 415 --batch 16 --epochs 30 --data dataset.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=dataset.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=30, batch_size=16, imgsz=415, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.9.6 torch-2.0.0 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=2
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     18879  models.yolo.Detect                      [2, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7025023 parameters, 7025023 gradients, 16.0 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# WARNING ⚠️ --img-size 415 must be multiple of max stride 32, updating to 416
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# train: Scanning /Users/akhilsharma/Projects/Mask-NoMask-YOLO/dataset/labels/trai
# train: WARNING ⚠️ /Users/akhilsharma/Projects/Mask-NoMask-YOLO/dataset/images/train/000_1OC3DT.jpg: corrupt JPEG restored and saved
# train: WARNING ⚠️ /Users/akhilsharma/Projects/Mask-NoMask-YOLO/dataset/images/train/china-virus.jpg: corrupt JPEG restored and saved
# train: Caching images (0.2GB ram): 100%|██████████| 736/736 [00:01<00:00, 625.69
# val: Scanning /Users/akhilsharma/Projects/Mask-NoMask-YOLO/dataset/labels/val.ca
# val: WARNING ⚠️ /Users/akhilsharma/Projects/Mask-NoMask-YOLO/dataset/images/val/1249493.jpg: corrupt JPEG restored and saved
# val: Caching images (0.1GB ram): 100%|██████████| 184/184 [00:01<00:00, 145.85it
#
# AutoAnchor: 4.98 anchors/target, 0.998 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp4/labels.jpg...
# Image sizes 416 train, 416 val
# Using 8 dataloader workers
# Logging results to runs/train/exp4
# Starting training for 30 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/29         0G      0.113    0.04234    0.02387        128        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.063     0.0771     0.0316    0.00681
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/29         0G     0.0855    0.04318    0.01546        170        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.643      0.185      0.151     0.0442
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/29         0G    0.07639    0.03657    0.01472        139        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.624      0.148     0.0921     0.0225
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/29         0G    0.07284    0.03407    0.01351        184        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.745      0.278      0.328      0.118
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/29         0G    0.06334    0.03325    0.01165        116        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.365      0.599       0.45      0.175
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/29         0G    0.05776    0.03317    0.00884        123        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.613      0.633       0.66      0.261
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/29         0G    0.05368    0.03226   0.007159        134        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.627      0.683      0.677       0.29
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        7/29         0G    0.05111    0.03177   0.005837        107        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.703       0.68      0.712      0.326
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/29         0G    0.04871    0.02974   0.005465        137        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.695      0.678       0.72      0.322
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/29         0G    0.04725    0.03037   0.004792        180        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.733      0.754      0.785      0.383
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/29         0G    0.04463    0.03061   0.004347        110        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.798      0.747      0.807      0.383
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/29         0G    0.04384    0.02996    0.00422        153        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.853       0.74      0.803      0.369
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/29         0G    0.04263    0.03051   0.003731        236        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.795      0.784      0.802       0.39
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/29         0G    0.04197    0.03011   0.003548        145        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.825      0.788      0.824        0.4
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/29         0G    0.04024    0.02792   0.003328        189        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.841      0.779       0.83      0.409
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/29         0G    0.03983    0.02907   0.003176        112        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.884      0.768      0.835      0.418
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/29         0G    0.03755    0.02814   0.002883        235        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.849      0.782      0.837      0.418
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/29         0G    0.03778    0.02898   0.002649        123        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.874      0.784      0.842       0.42
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       18/29         0G    0.03723    0.02785   0.002639        141        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.885      0.789      0.853      0.431
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/29         0G    0.03636    0.02971   0.002621        151        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.842      0.801      0.842      0.432
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       20/29         0G     0.0348    0.02727   0.002532        193        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042       0.89      0.787      0.851      0.439
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       21/29         0G    0.03378    0.02632    0.00229        125        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.852       0.81       0.85      0.443
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       22/29         0G    0.03363    0.02723    0.00237        140        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.862      0.815      0.862      0.455
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       23/29         0G    0.03322    0.02721   0.002271        168        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.882      0.825       0.87      0.455
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       24/29         0G    0.03256    0.02627   0.001966        169        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.852      0.822      0.868      0.459
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       25/29         0G    0.03211    0.02693   0.001921         97        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.882      0.807      0.872      0.466
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       26/29         0G    0.03207    0.02611    0.00185        112        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.877      0.819      0.868      0.464
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       27/29         0G    0.03125     0.0252   0.002011        174        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.891      0.817       0.87      0.468
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       28/29         0G    0.03078    0.02637   0.001771        139        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042       0.89      0.803      0.866      0.469
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       29/29         0G    0.03029    0.02481   0.001696         92        416: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.891      0.794       0.87      0.467
#
# 30 epochs completed in 2.173 hours.
# Optimizer stripped from runs/train/exp4/weights/last.pt, 14.3MB
# Optimizer stripped from runs/train/exp4/weights/best.pt, 14.3MB
#
# Validating runs/train/exp4/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all        184       1042      0.886      0.801      0.865      0.469
#                No-Mask        184        264      0.862      0.712      0.799      0.369
#                   Mask        184        778      0.909       0.89       0.93      0.568
# Results saved to runs/train/exp4
